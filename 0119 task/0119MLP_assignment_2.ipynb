# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from mpl_toolkits.mplot3d import Axes3D
import torch
import torch.nn as nn
import torch.nn.functional as F
from sklearn.model_selection import train_test_split

# %%
# Device configuration
if torch.cuda.is_available():
  device = torch.device('cuda')
else:
  device = torch.device('cpu')

print('device:', device)
# Out:
# device: cuda

# %%
'''
# function_2d
# Input : x , y
# output : z = f(x,y)
'''
def function_2d(x,y):
  term_sqrt = np.sqrt(x*x+y*y)
  term1 = np.sin(20*term_sqrt)/(20*term_sqrt)
  term2 = (1/5)*np.cos(10*term_sqrt)
  term3 = y/2 - 0.3

  label = term1 + term2 + term3

  return label

'''
# generate_data
# input : dim (int)
# output : (10000, 3) dataset, type : np.array
  - first column : x
  - second column : y
  - third column : f(x,y) (True label)
'''
def generate_data(dim):
  x = np.linspace(-1, 1, dim)
  y = np.linspace(-1, 1, dim)
  xx, yy = np.meshgrid(x,y)
  zz = function_2d(xx,yy)

  data_1 = xx.reshape(-1,1)
  data_2 = yy.reshape(-1,1)
  label = zz.reshape(-1,1)

  dataset = np.hstack((data_1, data_2))
  dataset = np.hstack((dataset, label))

  return dataset

# %%
fig = plt.figure(figsize=(9, 6))
ax = fig.add_subplot(111, projection='3d')
x = np.linspace(-1, 1, 100)
y = np.linspace(-1, 1, 100)
xx, yy = np.meshgrid(x,y)
zz = function_2d(xx,yy)

surf = ax.plot_surface(xx, yy, zz, cmap='viridis')
surf.set_clim(-1.0, 1.0)
ax.view_init(30,-60)
ax.set_zticks([-1,1])
ax.zaxis.set_major_locator(ticker.MultipleLocator(0.25))
plt.tight_layout()
plt.show()

# %%
class Mydataset(torch.utils.data.Dataset):
  def __init__(self, dataX_np , dataY_np):
    self.data_X = dataX_np.astype(np.float32)
    self.data_Y = dataY_np.astype(np.float32)

    print(f"My_dataset __init__ received : {self.data_X.shape}, {self.data_Y.shape} ")

  def __getitem__(self, index):
    batch = self.data_X[index]
    target = self.data_Y[index]

    return batch, target
  def __len__(self):
    return len(self.data_X)

# %%
dataset = generate_data(100)

# %%
x = dataset[:, :2]
y = dataset[:,2:]

# train-temp 분리 (7:3)
x_train, x_temp, y_train, y_temp = train_test_split(x,y,test_size=0.3, shuffle=True)

# temp 에서 validation-test 분리 3 -> 1.5:1.5
x_val, x_test, y_val, y_test = train_test_split(x_temp, y_temp, test_size=0.5,shuffle=True)

print(x_train.shape)
print(x_val.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (7000, 2)
# (1500, 2)
# (1500, 2)
# (1500, 1)

# %%
class SimpleMLP(nn.Module):
  def __init__(self, inp_ = 2, output_ = 1):
      super(SimpleMLP, self).__init__()
      self.fc1=nn.Linear(2,128)
      self.fc2=nn.Linear(128,64)
      self.fc3=nn.Linear(64,32)
      self.fc4=nn.Linear(32,16)
      self.fc5=nn.Linear(16,8)
      self.fc6=nn.Linear(8,4)
      self.fc7=nn.Linear(4,2)
      self.fc8=nn.Linear(2,1)

  def forward(self, x):
      x = self.fc1(x)
      x = F.relu(x)
      x = self.fc2(x)
      x = F.relu(x)
      x = self.fc3(x)
      x = F.relu(x)
      x = self.fc4(x)
      x = F.relu(x)
      x = self.fc5(x)
      x = F.relu(x)
      x = self.fc6(x)
      x = F.relu(x)
      x = self.fc7(x)
      x = F.relu(x)
      x = self.fc8(x)

      return x

# %%
batch_size = 1000000
train_loader = torch.utils.data.DataLoader(Mydataset(x_train, y_train), batch_size= batch_size, shuffle=False, drop_last = False)
valid_loader = torch.utils.data.DataLoader(Mydataset(x_val, y_val), batch_size=batch_size, shuffle=False, drop_last = False)
test_loader = torch.utils.data.DataLoader(Mydataset(x_test, y_test), batch_size=batch_size, shuffle=False, drop_last = False)
# Out:
# My_dataset __init__ received : (7000, 2), (7000, 1)
# My_dataset __init__ received : (1500, 2), (1500, 1)
# My_dataset __init__ received : (1500, 2), (1500, 1)

# %%
from statistics import mean
import time

def train(model, criterion_, optimizer_, scheduler_, num_epochs=40, first_epoch=1):

  train_losses = []
  valid_losses = []
  test_losses = []

  print("----------------------------------------------------------------------------")

  start_time = time.time()
  for epoch in range(first_epoch, first_epoch + num_epochs):
    # train phase
    model.train()

    # batch_loss
    batch_losses = []

    for samples, labels in train_loader:

      # Move the training data to the GPU
      samples = samples.to(device)
      labels = labels.to(device)

      # clear previous gradient computation
      optimizer_.zero_grad()

      # forward propagation
      outputs = model(samples)

      # calculate the loss
      loss = criterion_.forward(outputs, labels)
      batch_losses.append(loss.item())

      # backpropagate to compute gradients
      loss.backward()

      # update model weights
      optimizer_.step()

    # Train loss 를 저장합니다.
    train_losses.append(mean(batch_losses))

    # validation phase
    # Dropout, BatchNormalization 과 같은 layer 가 동작하지 않도록 합니다.
    model.eval()

    # We don't need gradients for test, so wrap in
    # no_grad to save memory
    # 기울기 Gradient 를 계산하지 않으며 backpropagation 을 하지 않습니다.
    with torch.no_grad():

      for samples, labels in valid_loader:

        # Move the training batch to the GPU
        samples = samples.to(device)
        labels = labels.to(device)

        # forward propagation
        outputs = model(samples)

        # calculate the loss
        loss = criterion_(outputs, labels)
        valid_losses.append(loss.item())

    for samples, labels in test_loader:
        # Move the training batch to the GPU
        samples = samples.to(device)
        labels = labels.to(device)

        # forward propagation
        outputs = model(samples)

        # calculate the loss
        loss = criterion_(outputs, labels)
        test_losses.append(loss.item())


    # 원하는 Epoch 마다 결과 출력
    if (epoch) % 100== 0 :
      curr_time = round(time.time()-start_time)
      train_rec = round(train_losses[-1],5)
      valid_rec = round(valid_losses[-1],5)
      test_rec = round(test_losses[-1],5)
      print('Epoch', epoch, ' / ',num_epochs)
      print(f"\t [Train loss : {train_rec}] [Validation loss : {valid_rec}] [Test loss : {test_rec}] [curr LR = {scheduler_.get_last_lr()}],[elapsed_time = {curr_time}sec] ")

    # Learning rate Scheduling
    # Scheduler 에 따라 learning rate 를 조절합니다.
    scheduler_.step()

  print(f"\nTrain Ended, total_elapsed_time = {round(time.time()-start_time)} ")
  print("--------------------------------------------------------------------")
  
  # Loss 값 반환
  return train_losses, valid_losses, test_losses

# %%
model = SimpleMLP()
model.to(device)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)#보통 결과 동일문제 발생시 lr이 문제일 가능성이 높음! 
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=2000, gamma=0.5)
train_losses, valid_losses, test_losses = train(model, criterion_ = criterion, optimizer_ = optimizer, scheduler_ = scheduler, num_epochs=6000)
# Out:
# ----------------------------------------------------------------------------
# Epoch 100  /  6000
# 	 [Train loss : 0.02972] [Validation loss : 0.02865] [Test loss : 0.03239] [curr LR = [0.01]],[elapsed_time = 9sec]
# Epoch 200  /  6000
# 	 [Train loss : 0.02673] [Validation loss : 0.02644] [Test loss : 0.02912] [curr LR = [0.01]],[elapsed_time = 19sec]
# Epoch 300  /  6000
# 	 [Train loss : 0.02504] [Validation loss : 0.02468] [Test loss : 0.02747] [curr LR = [0.01]],[elapsed_time = 30sec]
# Epoch 400  /  6000
# 	 [Train loss : 0.0208] [Validation loss : 0.0203] [Test loss : 0.02247] [curr LR = [0.01]],[elapsed_time = 40sec]
# Epoch 500  /  6000
# 	 [Train loss : 0.01403] [Validation loss : 0.01413] [Test loss : 0.01619] [curr LR = [0.01]],[elapsed_time = 50sec]
# Epoch 600  /  6000
# 	 [Train loss : 0.01078] [Validation loss : 0.01021] [Test loss : 0.01244] [curr LR = [0.01]],[elapsed_time = 60sec]
# Epoch 700  /  6000
# 	 [Train loss : 0.01027] [Validation loss : 0.00922] [Test loss : 0.01116] [curr LR = [0.01]],[elapsed_time = 70sec]
# Epoch 800  /  6000
# 	 [Train loss : 0.00358] [Validation loss : 0.00339] [Test loss : 0.0041] [curr LR = [0.01]],[elapsed_time = 80sec]
# Epoch 900  /  6000
# 	 [Train loss : 0.00126] [Validation loss : 0.0012] [Test loss : 0.00126] [curr LR = [0.01]],[elapsed_time = 91sec]
# Epoch 1000  /  6000
# 	 [Train loss : 0.00091] [Validation loss : 0.00095] [Test loss : 0.00101] [curr LR = [0.01]],[elapsed_time = 100sec]
# Epoch 1100  /  6000
# 	 [Train loss : 0.00078] [Validation loss : 0.00082] [Test loss : 0.00091] [curr LR = [0.01]],[elapsed_time = 111sec]
# Epoch 1200  /  6000
# 	 [Train loss : 0.00179] [Validation loss : 0.0014] [Test loss : 0.00143] [curr LR = [0.01]],[elapsed_time = 121sec]
# Epoch 1300  /  6000
# 	 [Train loss : 0.00066] [Validation loss : 0.00071] [Test loss : 0.0008] [curr LR = [0.01]],[elapsed_time = 131sec]
# Epoch 1400  /  6000
# 	 [Train loss : 0.00071] [Validation loss : 0.00081] [Test loss : 0.00085] [curr LR = [0.01]],[elapsed_time = 144sec]
# Epoch 1500  /  6000
# 	 [Train loss : 0.00079] [Validation loss : 0.00094] [Test loss : 0.00099] [curr LR = [0.01]],[elapsed_time = 157sec]
# Epoch 1600  /  6000
# 	 [Train loss : 0.00063] [Validation loss : 0.00068] [Test loss : 0.00074] [curr LR = [0.01]],[elapsed_time = 167sec]
# Epoch 1700  /  6000
# 	 [Train loss : 0.0005] [Validation loss : 0.00052] [Test loss : 0.00058] [curr LR = [0.01]],[elapsed_time = 177sec]
# Epoch 1800  /  6000
# 	 [Train loss : 0.00065] [Validation loss : 0.00093] [Test loss : 0.00093] [curr LR = [0.01]],[elapsed_time = 187sec]
# Epoch 1900  /  6000
# 	 [Train loss : 0.00061] [Validation loss : 0.00062] [Test loss : 0.00067] [curr LR = [0.01]],[elapsed_time = 198sec]
# Epoch 2000  /  6000
# 	 [Train loss : 0.0006] [Validation loss : 0.00059] [Test loss : 0.00062] [curr LR = [0.01]],[elapsed_time = 208sec]
# Epoch 2100  /  6000
# 	 [Train loss : 0.00039] [Validation loss : 0.00041] [Test loss : 0.00045] [curr LR = [0.005]],[elapsed_time = 218sec]
# Epoch 2200  /  6000
# 	 [Train loss : 0.00037] [Validation loss : 0.00039] [Test loss : 0.00043] [curr LR = [0.005]],[elapsed_time = 228sec]
# Epoch 2300  /  6000
# 	 [Train loss : 0.00036] [Validation loss : 0.00038] [Test loss : 0.00041] [curr LR = [0.005]],[elapsed_time = 238sec]
# Epoch 2400  /  6000
# 	 [Train loss : 0.00034] [Validation loss : 0.00036] [Test loss : 0.0004] [curr LR = [0.005]],[elapsed_time = 248sec]
# Epoch 2500  /  6000
# 	 [Train loss : 0.00033] [Validation loss : 0.00035] [Test loss : 0.00038] [curr LR = [0.005]],[elapsed_time = 258sec]
# Epoch 2600  /  6000
# 	 [Train loss : 0.00031] [Validation loss : 0.00033] [Test loss : 0.00037] [curr LR = [0.005]],[elapsed_time = 269sec]
# Epoch 2700  /  6000
# 	 [Train loss : 0.0003] [Validation loss : 0.00032] [Test loss : 0.00035] [curr LR = [0.005]],[elapsed_time = 281sec]
# Epoch 2800  /  6000
# 	 [Train loss : 0.00029] [Validation loss : 0.0003] [Test loss : 0.00034] [curr LR = [0.005]],[elapsed_time = 291sec]
# Epoch 2900  /  6000
# 	 [Train loss : 0.00028] [Validation loss : 0.00029] [Test loss : 0.00033] [curr LR = [0.005]],[elapsed_time = 300sec]
# Epoch 3000  /  6000
# 	 [Train loss : 0.00026] [Validation loss : 0.00028] [Test loss : 0.00031] [curr LR = [0.005]],[elapsed_time = 310sec]
# Epoch 3100  /  6000
# 	 [Train loss : 0.00026] [Validation loss : 0.00028] [Test loss : 0.00031] [curr LR = [0.005]],[elapsed_time = 320sec]
# Epoch 3200  /  6000
# 	 [Train loss : 0.00047] [Validation loss : 0.00054] [Test loss : 0.00056] [curr LR = [0.005]],[elapsed_time = 330sec]
# Epoch 3300  /  6000
# 	 [Train loss : 0.00028] [Validation loss : 0.0003] [Test loss : 0.00033] [curr LR = [0.005]],[elapsed_time = 340sec]
# Epoch 3400  /  6000
# 	 [Train loss : 0.00023] [Validation loss : 0.00025] [Test loss : 0.00028] [curr LR = [0.005]],[elapsed_time = 349sec]
# Epoch 3500  /  6000
# 	 [Train loss : 0.00046] [Validation loss : 0.00057] [Test loss : 0.00058] [curr LR = [0.005]],[elapsed_time = 359sec]
# Epoch 3600  /  6000
# 	 [Train loss : 0.00024] [Validation loss : 0.00024] [Test loss : 0.00027] [curr LR = [0.005]],[elapsed_time = 369sec]
# Epoch 3700  /  6000
# 	 [Train loss : 0.00023] [Validation loss : 0.00025] [Test loss : 0.00028] [curr LR = [0.005]],[elapsed_time = 379sec]
# Epoch 3800  /  6000
# 	 [Train loss : 0.00023] [Validation loss : 0.00024] [Test loss : 0.00027] [curr LR = [0.005]],[elapsed_time = 389sec]
# Epoch 3900  /  6000
# 	 [Train loss : 0.00023] [Validation loss : 0.00023] [Test loss : 0.00025] [curr LR = [0.005]],[elapsed_time = 399sec]
# Epoch 4000  /  6000
# 	 [Train loss : 0.0002] [Validation loss : 0.00021] [Test loss : 0.00024] [curr LR = [0.005]],[elapsed_time = 409sec]
# Epoch 4100  /  6000
# 	 [Train loss : 0.00018] [Validation loss : 0.0002] [Test loss : 0.00023] [curr LR = [0.0025]],[elapsed_time = 419sec]
# Epoch 4200  /  6000
# 	 [Train loss : 0.00018] [Validation loss : 0.0002] [Test loss : 0.00022] [curr LR = [0.0025]],[elapsed_time = 429sec]
# Epoch 4300  /  6000
# 	 [Train loss : 0.00017] [Validation loss : 0.00019] [Test loss : 0.00022] [curr LR = [0.0025]],[elapsed_time = 440sec]
# Epoch 4400  /  6000
# 	 [Train loss : 0.00017] [Validation loss : 0.00019] [Test loss : 0.00022] [curr LR = [0.0025]],[elapsed_time = 450sec]
# Epoch 4500  /  6000
# 	 [Train loss : 0.00017] [Validation loss : 0.00019] [Test loss : 0.00021] [curr LR = [0.0025]],[elapsed_time = 460sec]
# Epoch 4600  /  6000
# 	 [Train loss : 0.00016] [Validation loss : 0.00019] [Test loss : 0.00021] [curr LR = [0.0025]],[elapsed_time = 470sec]
# Epoch 4700  /  6000
# 	 [Train loss : 0.00016] [Validation loss : 0.00018] [Test loss : 0.0002] [curr LR = [0.0025]],[elapsed_time = 481sec]
# Epoch 4800  /  6000
# 	 [Train loss : 0.00016] [Validation loss : 0.00018] [Test loss : 0.0002] [curr LR = [0.0025]],[elapsed_time = 492sec]
# Epoch 4900  /  6000
# 	 [Train loss : 0.00015] [Validation loss : 0.00018] [Test loss : 0.0002] [curr LR = [0.0025]],[elapsed_time = 502sec]
# Epoch 5000  /  6000
# 	 [Train loss : 0.00015] [Validation loss : 0.00018] [Test loss : 0.00019] [curr LR = [0.0025]],[elapsed_time = 512sec]
# Epoch 5100  /  6000
# 	 [Train loss : 0.00015] [Validation loss : 0.00017] [Test loss : 0.00019] [curr LR = [0.0025]],[elapsed_time = 523sec]
# Epoch 5200  /  6000
# 	 [Train loss : 0.00015] [Validation loss : 0.00017] [Test loss : 0.00019] [curr LR = [0.0025]],[elapsed_time = 533sec]
# Epoch 5300  /  6000
# 	 [Train loss : 0.00015] [Validation loss : 0.00017] [Test loss : 0.00019] [curr LR = [0.0025]],[elapsed_time = 542sec]
# Epoch 5400  /  6000
# 	 [Train loss : 0.00014] [Validation loss : 0.00016] [Test loss : 0.00018] [curr LR = [0.0025]],[elapsed_time = 552sec]
# Epoch 5500  /  6000
# 	 [Train loss : 0.00014] [Validation loss : 0.00017] [Test loss : 0.00018] [curr LR = [0.0025]],[elapsed_time = 562sec]
# Epoch 5600  /  6000
# 	 [Train loss : 0.00014] [Validation loss : 0.00016] [Test loss : 0.00017] [curr LR = [0.0025]],[elapsed_time = 574sec]
# Epoch 5700  /  6000
# 	 [Train loss : 0.00013] [Validation loss : 0.00016] [Test loss : 0.00017] [curr LR = [0.0025]],[elapsed_time = 584sec]
# Epoch 5800  /  6000
# 	 [Train loss : 0.00013] [Validation loss : 0.00016] [Test loss : 0.00017] [curr LR = [0.0025]],[elapsed_time = 594sec]
# Epoch 5900  /  6000
# 	 [Train loss : 0.00014] [Validation loss : 0.00017] [Test loss : 0.00018] [curr LR = [0.0025]],[elapsed_time = 604sec]
# Epoch 6000  /  6000
# 	 [Train loss : 0.00016] [Validation loss : 0.00021] [Test loss : 0.00022] [curr LR = [0.0025]],[elapsed_time = 614sec]
#
# Train Ended, total_elapsed_time = 614
# --------------------------------------------------------------------

# %%
def plot_result(train_loss, val_loss, test_loss):
  plt.figure(figsize=(20,8))
  plt.plot(train_loss, label='Train Loss', linewidth='3')
  plt.plot(val_loss, label='Validation Loss', linewidth='3')
  plt.plot(test_loss, label='Test Loss', linewidth='3')
  plt.grid()
  plt.rc('xtick', labelsize=12)
  plt.rc('ytick', labelsize=12)
  plt.legend()
  plt.rc('legend', fontsize=15)
  plt.xlabel('Number of Eopch')
  plt.ylabel('MSE Loss')
  plt.rc('axes', labelsize=17)

# %%
plot_result(train_losses, valid_losses, test_losses)

# %%
def visual_graph(model):
  x = np.linspace(-1, 1, 100)
  y = np.linspace(-1, 1, 100)
  xx,yy = np.meshgrid(x,y)
  xx = xx.reshape(-1,1)
  yy = yy.reshape(-1,1)
  inp_np = np.hstack((xx,yy))
  inp_tensor = torch.Tensor(inp_np)
  inp_tensor = inp_tensor.to(device)
  zz = model(inp_tensor)
  pred_output = zz.detach().cpu().numpy()
  fig = plt.figure(figsize=(9, 6))
  ax = fig.add_subplot(111, projection='3d')
  xx = xx.reshape(100,100)
  yy = yy.reshape(100,100)
  pred_output = pred_output.reshape(100,100)
  surf = ax.plot_surface(xx, yy, pred_output, cmap='viridis')
  surf.set_clim(-1.0, 1.0)
  ax.view_init(30,-60)
  ax.set_zticks([-1,1])
  ax.zaxis.set_major_locator(ticker.MultipleLocator(0.25))
  plt.tight_layout()
  plt.show()

# %%
visual_graph(model)
